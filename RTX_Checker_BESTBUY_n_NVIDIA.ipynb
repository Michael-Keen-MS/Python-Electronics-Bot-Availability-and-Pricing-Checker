# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests
import json
import time
import winsound
import datetime
import webbrowser
from IPython.display import clear_output

# %%
payload = {}
headers = {
  'authority': 'api-prod.nvidia.com',
  'accept': 'application/json, text/javascript, */*; q=0.01',
  'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
  'dnt': '1',
  'origin': 'https://www.nvidia.com',
  'sec-fetch-site': 'same-site',
  'sec-fetch-mode': 'cors',
  'sec-fetch-dest': 'empty',
  'referer': 'https://www.nvidia.com/en-us/geforce/graphics-cards/30-series/rtx-3090/',
  'accept-language': 'en-CA,en-GB;q=0.9,en-US;q=0.8,en;q=0.7'
}

# %%
links = {"bb_FE_3080":"https://www.bestbuy.com/site/nvidia-geforce-rtx-3080-10gb-gddr6x-pci-express-4-0-graphics-card-titanium-and-black/6429440.p?skuId=6429440"
         ,"bb_Gigabyte_3080":"https://www.bestbuy.com/site/pny-geforce-rtx-3080-10gb-xlr8-gaming-epic-x-rgb-triple-fan-graphics-card/6432655.p?skuId=6432655"
         ,"bb_MSI_3080":"https://www.bestbuy.com/site/msi-geforce-rtx-3080-ventus-3x-10g-oc-bv-gddr6x-pci-express-4-0-graphic-card-black-silver/6430175.p?skuId=6430175"
         ,"bb_EVGA_3080":"https://www.bestbuy.com/site/evga-geforce-rtx-3080-10gb-gddr6x-pci-express-4-0-graphics-card/6432399.p?skuId=6432399"
         ,"bb_ASUS_3080":"https://www.bestbuy.com/site/asus-geforce-rtx-3080-10gb-gddr6x-pci-express-4-0-strix-graphics-card-black/6432445.p?skuId=6432445#tabbed-customerreviews"
         ,"bb_Gigabyte2_3080":"https://www.bestbuy.com/site/gigabyte-geforce-rtx-3080-10g-gddr6x-pci-express-4-0-graphics-card-black/6430620.p?skuId=6430620"
         ,"bb_EVGA2_3080":"https://www.bestbuy.com/site/evga-geforce-rtx-3080-10gb-gddr6x-pci-express-4-0-graphics-card/6432400.p?skuId=6432400"         
         ,"bb_FE_3070":"https://www.bestbuy.com/site/nvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black/6429442.p?skuId=6429442"
         ,"bb_Gigabyte3_3070":"https://www.bestbuy.com/site/gigabyte-geforce-rtx-3070-8g-gddr6-pci-express-4-0-graphics-card-black/6437912.p?skuId=6437912"
         ,"bb_MSI_VENTUS3_3070":"https://www.bestbuy.com/site/msi-geforce-rtx-3070-ventus-3x-oc-bv-8gb-gddr6-pci-express-4-0-graphics-card-black/6438278.p?skuId=6438278"
         ,"bb_EVGA_XC3_3070":"https://www.bestbuy.com/site/evga-geforce-rtx-3070-xc3-black-gaming-8gb-gddr6x-pci-express-4-0-graphics-card/6439300.p?skuId=6439300"
         ,"bb_ASUS_TUF_3070":"https://www.bestbuy.com/site/asus-tuf-rtx3070-8gb-gddr6-pci-express-4-0-graphics-card-black/6439128.p?skuId=6439128"
         ,"bb_Gigabyte3_WT_3070":"https://www.bestbuy.com/site/gigabyte-geforce-rtx-3070-8g-gddr6-pci-express-4-0-graphics-card-white/6439385.p?skuId=6439385"
         ,"bb_PNY3_EPICX_3070":"https://www.bestbuy.com/site/pny-geforce-rtx-3070-8gb-xlr8-gaming-epic-x-rgb-triple-fan-graphics-card/6432653.p?skuId=6432653"
         ,"bb_Gigabyte_AORUS_3070":"https://www.bestbuy.com/site/gigabyte-geforce-rtx-3070-8g-gddr6-pci-express-4-0-graphics-card-black/6439384.p?skuId=6439384"
         ,"bb_PNY2_3070":"https://www.bestbuy.com/site/pny-geforce-rtx-3070-8gb-dual-fan-graphics-card/6432654.p?skuId=6432654"
         ,"bb_EVGA_FTW3_3070":"https://www.bestbuy.com/site/evga-geforce-rtx-3070-ftw3-ultra-gaming-8gb-gddr6x-pci-express-4-0-graphics-card/6439301.p?skuId=6439301"
         ,"bb_ASUS_ROGSTRIX_3070":"https://www.bestbuy.com/site/asus-rog-strix-rtx3070-8gb-gddr6-pci-express-4-0-graphics-card-black/6439127.p?skuId=6439127"
         ,"bb_Gigabyte3_2_3070":"https://www.bestbuy.com/site/gigabyte-geforce-rtx-3070-8g-gddr6-pci-express-4-0-graphics-card-black/6437909.p?skuId=6437909"
         ,"TEST_HDMI":"https://www.bestbuy.com/site/dynex-6-hdmi-cable-black/6405508.p?skuId=6405508"
         ,"bb_FE_3060":"https://www.bestbuy.com/site/nvidia-geforce-rtx-3060-ti-8gb-gddr6-pci-express-4-0-graphics-card-steel-and-black/6439402.p?skuId=6439402"
         ,"bb_GIGABYTE_3060":"https://www.bestbuy.com/site/gigabyte-nvidia-geforce-rtx-3060-ti-gaming-oc-8g-gddr6-pci-express-4-0-graphics-card-black/6442484.p?skuId=6442484"
         ,"bb_MSI_3060":"https://www.bestbuy.com/site/msi-geforce-rtx-3060-ti-ventus-2x-oc-bv-8gb-gddr6-pci-express-4-0-graphics-card-black-black/6441172.p?skuId=6441172"
         ,"bb_EAGLE_3060":"https://www.bestbuy.com/site/gigabyte-nvidia-geforce-rtx-3060-ti-eagle-oc-8g-gddr6-pci-express-4-0-graphics-card-black/6442485.p?skuId=6442485"
         ,"ASUS_3070_OC_ED_TRIFAN":"https://store.asus.com/us/item/202010AM310000002/A50243-ASUS-TUF-Gaming-NVIDIA-GeForce-RTX-3070-OC-Edition-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6%2C-HDMI-2.1-%2C-DisplayPort-1.4a%2C-Dual-ball-Fan-Bearings%2C-Military-grade-Certification%2C-GPU-Tweak-II%29"
         ,"ASUS_3070_OC_ED_KO":"https://store.asus.com/us/item/202011AM070000002/graphicscards-ASUS-KO-NVIDIA-GeForce-RTX-3070-OC-Edition-8GB-GDDR6-Gaming-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6-memory%2C-HDMI-2.1%2C-DisplayPort-1.4a%2C-Axial-tech-Fan-Design%2C-0dB-technology%2C-Enduring-capacitors%29"
         ,"ASUS_3070_OC_ED_DUAL":"https://store.asus.com/us/item/202010AM310000003/graphicscards-ASUS-DUAL-NVIDIA-GeForce-RTX-3070-OC-Edition-Gaming-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6-memory%2C-HDMI-2.1%2C-DisplayPort-1.4a%2C-Axial-tech-Fan-Design%2C-Dual-BIOS%2C-Protective-Backplate%2C-GPU-Tweak-II%29"
         ,"ASUS_3070_OC_ED_ROG_TRIFAN":"https://store.asus.com/us/item/202010AM310000001/graphicscards-ASUS-ROG-STRIX-NVIDIA-GeForce-RTX-3070-Gaming-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6%2C-HDMI-2.1%2C-DisplayPort-1.4a%2C-Axial-tech-Fan-Design%2C-2.9-slot%2C-Super-Alloy-Power-II%2C-GPU-Tweak-II%29"
         ,"ASUS_3070_OC_DUAL":"https://store.asus.com/us/item/202011AM070000003/graphicscards-ASUS-DUAL-NVIDIA-GeForce-RTX-3070-Gaming-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6-memory%2C-HDMI-2.1%2C-DisplayPort-1.4a%2C-Axial-tech-Fan-Design%2C-Dual-BIOS%2C-Protective-Backplate%2C-GPU-Tweak-II%29"
#          ,"ASUS_2080_TI":"https://store.asus.com/us/item/202003AM270000002/graphicscards-ASUS-ROG-STRIX-GeForce-RTX-2080TI-Overclocked-11G-GDDR6-HDMI-DP-1.4-USB-Type-C-Gaming-Graphics-Card-%28ROG-STRIX-RTX-2080-O11G%29"         
         ,"ZOTAC_CHECK":"https://www.zotacstore.com/us/geforcer-gt-710-1gb-pcie-x-1-zt-71304-20l"
         ,"ZOTAC_3070_OC":"https://store.asus.com/us/item/202010AM310000003/graphicscards-ASUS-DUAL-NVIDIA-GeForce-RTX-3070-OC-Edition-Gaming-Graphics-Card-%28PCIe-4.0%2C-8GB-GDDR6-memory%2C-HDMI-2.1%2C-DisplayPort-1.4a%2C-Axial-tech-Fan-Design%2C-Dual-BIOS%2C-Protective-Backplate%2C-GPU-Tweak-II%29"

        }

headers = {"User-Agent":"Mozilla/5.0","cache-control":"max-age=0"}

is_sold_out_bb_FE_3080 = False
is_sold_out_bb_Gigabyte_3080 = False
is_sold_out_bb_MSI_3080 = False
is_sold_out_bb_EVGA_3080 = False
is_sold_out_bb_ASUS_3080 = False
is_sold_out_bb_Gigabyte2_3080 = True
is_sold_out_bb_EVGA2_3080 = False

is_sold_out_bb_FE_3070 = False
is_sold_out_bb_Gigabyte3_3070 = False
is_sold_out_bb_MSI_VENTUS3_3070 = False
is_sold_out_bb_EVGA_XC3_3070 = False
is_sold_out_bb_ASUS_TUF_3070 = False
is_sold_out_bb_Gigabyte3_WT_3070 = False
is_sold_out_bb_PNY3_EPICX_3070 = False
is_sold_out_bb_Gigabyte_AORUS_3070 = False
is_sold_out_bb_PNY2_3070 = False
is_sold_out_bb_EVGA_FTW3_3070 = False
is_sold_out_bb_ASUS_ROGSTRIX_3070 = False
is_sold_out_bb_Gigabyte3_2_3070 = False
is_sold_out_bb_TEST_HDMI = False

is_sold_out_bb_FE_3060 = False
is_sold_out_bb_GIGABYTE_3060 = False
is_sold_out_bb_MSI_3060 = False
is_sold_out_bb_EAGLE_3060 = False

is_sold_out_ASUS_3070_OC_ED_TRIFAN = False
is_sold_out_ASUS_3070_OC_ED_KO = False
is_sold_out_ASUS_3070_OC_ED_DUAL = False
is_sold_out_ASUS_3070_OC_ED_ROG_TRIFAN = False
is_sold_out_ASUS_3070_OC_DUAL = False
is_sold_out_ASUS_2080_TI = False

is_sold_out_ZOTAC_CHECK = False
is_sold_out_ZOTAC_3070_OC = False

# %%
def checkZOTAC():  
    global is_sold_out_ZOTAC_CHECK
    global is_sold_out_ZOTAC_3070_OC
#     global is_sold_out_ASUS_2080_TI                                                                       #USED AS TEST CASE AS ITEM WAS IN STOCK AT TIME
        
    is_sold_out_ZOTAC_CHECK = check_single_ZOTAC("ZOTAC_CHECK")
    is_sold_out_ZOTAC_3070_OC = check_single_ZOTAC("ZOTAC_3070_OC")
#     is_sold_out_ASUS_2080_TI = check_single_ASUS("ASUS_2080_TI")
        
    print ("ASUS SITE CARDS:  ========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  ZOTAC TEST CASE       :         ",not is_sold_out_ZOTAC_CHECK,
           "\n  ZOTAC 3070 OC:                  ",not is_sold_out_ZOTAC_3070_OC,
#            "\n  ASUS_2080_TI:                   ",not is_sold_out_ASUS_2080_TI,
           "\n\n\n")    
    
    if not is_sold_out_ZOTAC_CHECK or \
    not is_sold_out_ZOTAC_3070_OC:
        signal()
        
        
#     is_sold_out_ASUS_2080_TI or \ PUT BACK TO TEST KNOWN IN STOCK ITEM

# %%
def check3080():
    global is_sold_out_bb_FE_3080
    global is_sold_out_bb_Gigabyte_3080
    global is_sold_out_bb_MSI_3080
    global is_sold_out_bb_EVGA_3080
    global is_sold_out_bb_ASUS_3080
    global is_sold_out_bb_Gigabyte2_3080
    global is_sold_out_bb_EVGA2_3080
    
    
    is_sold_out_bb_FE_3080 = check_single("bb_FE_3080")
    is_sold_out_bb_Gigabyte_3080 = check_single("bb_Gigabyte_3080")
    is_sold_out_bb_MSI_3080 = check_single("bb_MSI_3080")
    is_sold_out_bb_EVGA_3080 = check_single("bb_EVGA_3080")
    is_sold_out_bb_ASUS_3080 = check_single("bb_ASUS_3080")
    is_sold_out_bb_Gigabyte2_3080 = check_single("bb_Gigabyte2_3080")
    is_sold_out_bb_EVGA2_3080 = check_single("bb_EVGA2_3080")    
   
    print ("BEST BUY 3080S: ===========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  FE 3080:                  ",not is_sold_out_bb_FE_3080,
           "\n  PNY 3080:                 ",not is_sold_out_bb_Gigabyte_3080,
           "\n  MSI 3080:                 ",not is_sold_out_bb_MSI_3080,
           "\n  EVGA 3080:                ",not is_sold_out_bb_EVGA_3080,
           "\n  ASUS 3080:                ",not is_sold_out_bb_ASUS_3080,
           "\n  Gigabyte 2 3080:          ",not is_sold_out_bb_Gigabyte2_3080,
           "\n  EVGA 2 3080:              ",not is_sold_out_bb_EVGA2_3080,"\n\n\n")
    
    
    if not is_sold_out_bb_FE_3080 or \
    not is_sold_out_bb_Gigabyte_3080 or \
    not is_sold_out_bb_MSI_3080 or \
    not is_sold_out_bb_EVGA_3080 or \
    not is_sold_out_bb_ASUS_3080 or \
    not is_sold_out_bb_Gigabyte2_3080 or \
    not is_sold_out_bb_EVGA2_3080:
        signal()

# %%
def check3070():
    
    global is_sold_out_bb_FE_3070
    global is_sold_out_bb_Gigabyte3_3070
    global is_sold_out_bb_MSI_VENTUS3_3070
    global is_sold_out_bb_EVGA_XC3_3070
    global is_sold_out_bb_ASUS_TUF_3070
    global is_sold_out_bb_Gigabyte3_WT_3070
    global is_sold_out_bb_PNY3_EPICX_3070
    global is_sold_out_bb_Gigabyte_AORUS_3070
    global is_sold_out_bb_PNY2_3070
    global is_sold_out_bb_EVGA_FTW3_3070
    global is_sold_out_bb_ASUS_ROGSTRIX_3070
    global is_sold_out_bb_Gigabyte3_2_3070
  
    
    is_sold_out_bb_FE_3070 = check_single("bb_FE_3070")
    is_sold_out_bb_Gigabyte3_3070 = check_single("bb_Gigabyte3_3070")
    is_sold_out_bb_MSI_VENTUS3_3070 = check_single("bb_MSI_VENTUS3_3070")
    is_sold_out_bb_EVGA_XC3_3070 = check_single("bb_EVGA_XC3_3070")
    is_sold_out_bb_ASUS_TUF_3070 = check_single("bb_ASUS_TUF_3070")
    is_sold_out_bb_Gigabyte3_WT_3070 = check_single("bb_Gigabyte3_WT_3070")
    is_sold_out_bb_PNY3_EPICX_3070 = check_single("bb_PNY3_EPICX_3070")
    is_sold_out_bb_Gigabyte_AORUS_3070 = check_single("bb_Gigabyte_AORUS_3070")
    is_sold_out_bb_PNY2_3070 = check_single("bb_PNY2_3070")
    is_sold_out_bb_EVGA_FTW3_3070 = check_single("bb_EVGA_FTW3_3070")
    is_sold_out_bb_ASUS_ROGSTRIX_3070 = check_single("bb_ASUS_ROGSTRIX_3070")
    is_sold_out_bb_Gigabyte3_2_3070 = check_single("bb_Gigabyte3_2_3070")
    
    print ("BEST BUY 3070S: ===========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  FE 3070:                        ",not is_sold_out_bb_FE_3070,
           "\n  Gigabyte3 3070:                 ",not is_sold_out_bb_Gigabyte3_3070,
           "\n  MSI VENTUS3 3070:               ",not is_sold_out_bb_MSI_VENTUS3_3070,
           "\n  EVGA XC3 3070:                  ",not is_sold_out_bb_EVGA_XC3_3070,
           "\n  ASUS TUF 3070:                  ",not is_sold_out_bb_ASUS_TUF_3070,
           "\n  Gigabyte TRIFAN WT 3070:        ",not is_sold_out_bb_Gigabyte3_WT_3070,
           "\n  PNY3 EPICX 3070:                ",not is_sold_out_bb_PNY3_EPICX_3070,
           "\n  Gigabyte AORUS 3070:            ",not is_sold_out_bb_Gigabyte_AORUS_3070,
           "\n  PNY2 3070:                      ",not is_sold_out_bb_PNY2_3070,
           "\n  EVGA FTW3 3070:                 ",not is_sold_out_bb_EVGA_FTW3_3070,
           "\n  ASUS ROG STRIX 3070:            ",not is_sold_out_bb_ASUS_ROGSTRIX_3070,
           "\n  Gigabyte TRI-FAN 2 3070:        ",not is_sold_out_bb_Gigabyte3_2_3070,
           "\n\n\n")
    
    
    if not is_sold_out_bb_FE_3070 or \
    not is_sold_out_bb_Gigabyte3_3070 or \
    not is_sold_out_bb_MSI_VENTUS3_3070 or \
    not is_sold_out_bb_EVGA_XC3_3070 or \
    not is_sold_out_bb_ASUS_TUF_3070 or \
    not is_sold_out_bb_Gigabyte3_WT_3070 or \
    not is_sold_out_bb_PNY3_EPICX_3070 or \
    not is_sold_out_bb_Gigabyte_AORUS_3070 or \
    not is_sold_out_bb_PNY2_3070 or \
    not is_sold_out_bb_EVGA_FTW3_3070 or \
    not is_sold_out_bb_ASUS_ROGSTRIX_3070 or \
    not is_sold_out_bb_Gigabyte3_2_3070:
        signal()

# %%
def check3060():
    global is_sold_out_bb_FE_3060
    global is_sold_out_bb_GIGABYTE_3060
    global is_sold_out_bb_MSI_3060
    global is_sold_out_bb_EAGLE_3060
    
        
    is_sold_out_bb_FE_3060 = check_single("bb_FE_3060")
    is_sold_out_bb_GIGABYTE_3060 = check_single("bb_GIGABYTE_3060")
    is_sold_out_bb_MSI_3060 = check_single("bb_MSI_3060")
    is_sold_out_bb_EAGLE_3060 = check_single("bb_EAGLE_3060")

    print ("BEST BUY 3060S: ===========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  FE 3060:                        ",not is_sold_out_bb_FE_3060,
           "\n  Gigabyte 3060:                  ",not is_sold_out_bb_GIGABYTE_3060,
           "\n  MSI 3060:                       ",not is_sold_out_bb_MSI_3060,
           "\n  Eagle 3060:                     ",not is_sold_out_bb_EAGLE_3060,
           "\n\n\n")
    
    
    if not is_sold_out_bb_FE_3060 or \
    not is_sold_out_bb_GIGABYTE_3060 or \
    not is_sold_out_bb_MSI_3060 or \
    not is_sold_out_bb_EAGLE_3060:
        signal()

# %%
def checkHDMITEST():
    
    global is_sold_out_bb_TEST_HDMI
  
    is_sold_out_bb_TEST_HDMI = check_single("TEST_HDMI")
    
    clear_output(wait=True)    
    
    print ("BEST BUY: ===========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  TEST HDMI:                ",not is_sold_out_bb_TEST_HDMI,"\n\n\n")    
    
    if not is_sold_out_bb_TEST_HDMI:
        signal()

# %%
def checkASUS():  
    global is_sold_out_ASUS_3070_OC_ED_TRIFAN
    global is_sold_out_ASUS_3070_OC_ED_KO
    global is_sold_out_ASUS_3070_OC_ED_DUAL
    global is_sold_out_ASUS_3070_OC_ED_ROG_TRIFAN
    global is_sold_out_ASUS_3070_OC_DUAL
#     global is_sold_out_ASUS_2080_TI                                                                       #USED AS TEST CASE AS ITEM WAS IN STOCK AT TIME
        
    is_sold_out_ASUS_3070_OC_ED_TRIFAN = check_single_ASUS("ASUS_3070_OC_ED_TRIFAN")
    is_sold_out_ASUS_3070_OC_ED_KO = check_single_ASUS("ASUS_3070_OC_ED_KO")
    is_sold_out_ASUS_3070_OC_ED_DUAL = check_single_ASUS("ASUS_3070_OC_ED_DUAL")
    is_sold_out_ASUS_3070_OC_ED_ROG_TRIFAN = check_single_ASUS("ASUS_3070_OC_ED_ROG_TRIFAN")
    is_sold_out_ASUS_3070_OC_DUAL = check_single_ASUS("ASUS_3070_OC_DUAL")
#     is_sold_out_ASUS_2080_TI = check_single_ASUS("ASUS_2080_TI")
        
    print ("ASUS SITE CARDS:  ========================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    
    print ("\n  ASUS 3070 OC ED TRIFAN:         ",not is_sold_out_ASUS_3070_OC_ED_TRIFAN,
           "\n  ASUS 3070 OC ED KO:             ",not is_sold_out_ASUS_3070_OC_ED_KO,
           "\n  ASUS 3070 OC ED DUAL:           ",not is_sold_out_ASUS_3070_OC_ED_DUAL,
           "\n  ASUS 3070 OC ED ROG TRIFAN:     ",not is_sold_out_ASUS_3070_OC_ED_ROG_TRIFAN,
           "\n  ASUS 3070 OC DUAL:              ",not is_sold_out_ASUS_3070_OC_DUAL,
#            "\n  ASUS_2080_TI:                   ",not is_sold_out_ASUS_2080_TI,
           "\n\n\n")    
    
    if not is_sold_out_ASUS_3070_OC_ED_TRIFAN or \
    not is_sold_out_ASUS_3070_OC_ED_KO or \
    not is_sold_out_ASUS_3070_OC_ED_DUAL or \
    not is_sold_out_ASUS_3070_OC_ED_ROG_TRIFAN or \
    not is_sold_out_ASUS_3070_OC_DUAL:
        signal()
        
        
#     is_sold_out_ASUS_2080_TI or \ PUT BACK TO TEST KNOWN IN STOCK ITEM

# %%
def check2():
    url = "https://api-prod.nvidia.com/direct-sales-shop/DR/products/en_us/USD/5438481700"
    response = requests.request("GET", url, headers=headers, data = payload)

    # print(response.json())

    jsonResponse = response.json()

    json_formatted_str = json.dumps(jsonResponse, indent=2)

    # print(json_formatted_str)

    print("NVIDIA WEBSITE 3080S: ===================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    for url in jsonResponse["products"]["product"]:
        print("\n  PRODUCT NAME:     ", url["displayName"], '\n', " IN STOCK?:        ", url["inventoryStatus"]["productIsInStock"].upper(), '\n', " PRODUCT STATUS:   ", url["inventoryStatus"]["status"], '\n', " PRICE:            ", url["pricing"]["formattedListPrice"])
        print("\n\n\n")

# %%
def check3():
    url = "https://api-prod.nvidia.com/direct-sales-shop/DR/products/en_us/USD/5438481800"

    response = requests.request("GET", url, headers=headers, data = payload)
    
    jsonResponse = response.json()

    json_formatted_str = json.dumps(jsonResponse, indent=2)
    
    print("NVIDIA WEBSITE 3070S: ===================================================================================", datetime.datetime.now().strftime("%H:%M:%S"))
    for url in jsonResponse["products"]["product"]:
        if not url["inventoryStatus"]["status"] == "PRODUCT_INVENTORY_OUT_OF_STOCK ":
            signal()
        print("\n  PRODUCT NAME:     ", url["displayName"], '\n', " IN STOCK?:        ", url["inventoryStatus"]["productIsInStock"].upper(), '\n', " PRODUCT STATUS:   ", url["inventoryStatus"]["status"], '\n', " PRICE:            ", url["pricing"]["formattedListPrice"])
        print("\n\n\n")

# %%
def check_single_ASUS(link_url):
    source = requests.get(links[link_url], headers=headers).text
    
    is_sold_out = source.__contains__('"availability":"http://schema.org/OutOfStock"') or source.__contains__('Dear Customers')
    if not is_sold_out:
        webbrowser.open(links[link_url])
        save_file = open(link_url+".html","w")
        save_file.write(source)
        save_file.close()
    time.sleep(0.05)
    return is_sold_out

# %%
def check_single_ZOTAC(link_url):
#     source = requests.get(links[link_url], headers=headers).text
    
#     is_sold_out = source.__contains__('')
#     if not is_sold_out:
#         webbrowser.open(links[link_url])
#         save_file = open(link_url+".html","w")
#         save_file.write(source)
#         save_file.close()
#     time.sleep(0.05)
#     return is_sold_out
    res = requests.Session().get('https://www.zotacstore.com/us/zt-71115-20l-o')
    cookies = dict(res.cookies)
    dict(res.cookies)
    print(requests.get("https://www.zotacstore.com/us/zt-71115-20l-o", headers=headers,     allow_redirects = True,     verify=False,      cookies=cookies).text)

# %%
def check_single(link_url):
    source = requests.get(links[link_url], headers=headers).text
    
    is_sold_out = source.__contains__("class=\"btn btn-disabled btn-lg btn-block add-to-cart-button\"") or source.__contains__("Coming Soon</button></div></div>")
    if not is_sold_out:
        webbrowser.open(links[link_url])
        save_file = open(link_url+".html","w")
        save_file.write(source)
        save_file.close()
    time.sleep(0.05)
    return is_sold_out

# %%
def signal():
    for i in range(1,5):
        for i in range(1, 10):
            winsound.Beep(i * 100, 200)
        time.sleep(0.5)

# %%
# UNCOMMENT ANY OF THE CHECKS YOU WISH TO RUN 

while True:
    
# ================================================== BEST BUY SITE TEST CHECK ==============================================

#     checkHDMITEST()             #UNCOMMENT THIS TO SEE WHAT HAPPENS WHEN A PRODUCT IS FOUND!

# ================================================== BEST BUY SITE CHECKS =================================================

    check3060()                   #CHECK BEST BUY FOR STOCK OF VARIOUS 3060S    
    check3070()                   #CHECK BEST BUY FOR STOCK OF VARIOUS 3070S    
#     check3080()                 #CHECK BEST BUY FOR STOCK OF VARIOUS 3080S    
   
# ================================================== ASUS SITE CHECKS =====================================================

    try:
        checkASUS() # block raising an exception
    except:
        pass # doing nothing on exception
                        #CHECK ASUS SITE FOR STOCK OF VARIOUS 3070S
    
# ================================================== ZOTAC SITE CHECKS ====================================================
    
#     checkZOTAC()                  #CHECK ZOTAC SITE FOR STOCK OF VARIOUS 3080S

# ================================================== NVIDIA SITE CHECKS ===================================================
    
    check2()                     #CHECK NVIDIA FOR STOCK OF FOUNDERS EDITION 3080
#     check3()                     #CHECK NVIDIA FOR STOCK OF FOUNDERS EDITION 3070 -- DOES NOT WORK AT THIS POINT; NO PRODUCT ID ASSOCIATED WITH FE 3070 FROM NVIDIA SITE YET

    time.sleep(0.0)
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-17-903fbd276e89> in <module>
#       9 # ================================================== BEST BUY SITE CHECKS =================================================
#      10
# ---> 11     check3060()                   #CHECK BEST BUY FOR STOCK OF VARIOUS 3060S
#      12     check3070()                   #CHECK BEST BUY FOR STOCK OF VARIOUS 3070S
#      13 #     check3080()                 #CHECK BEST BUY FOR STOCK OF VARIOUS 3080S
#
# <ipython-input-8-a721c9a26498> in check3060()
#       7
#       8     is_sold_out_bb_FE_3060 = check_single("bb_FE_3060")
# ----> 9     is_sold_out_bb_GIGABYTE_3060 = check_single("bb_GIGABYTE_3060")
#      10     is_sold_out_bb_MSI_3060 = check_single("bb_MSI_3060")
#      11     is_sold_out_bb_EAGLE_3060 = check_single("bb_EAGLE_3060")
#
# ...
